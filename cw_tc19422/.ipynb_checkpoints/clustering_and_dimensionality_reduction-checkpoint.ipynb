# %% [markdown]
# ## Clustering and dimensionality reduction

# %% [markdown]
# Download the Breast Cancer Wisconsin (Diagnostic) dataset from here. Do
# not use the “IMPORT IN PYTHON” option, just grab the zip file and unzip it. You will end up with two files: wdbc.data which is the data itself and
# wdbc.names which describes the data. As you can read, the data can be used
# to learn a classifier which uses 30 real-valued features to distinguish between
# benign and malignant tumours.
#
# In this section you are asked to compare the clusters produced by Gaussian mixture clustering to the true classes. But instead of clustering the data
# as is, you are first asked to use PCA to reduce the dimensionality down to 2
# dimensions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA, PCA
from sklearn.decomposition import FastICA
from sklearn.mixture import GaussianMixture
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Task 4
#
# Use PCA to reduce the data (without the class labels) from 30 dimensions to 2 dimensions and produce a scatter plot of this 2-dimensional
# data using colours to indicate the class label of each data point. In addition, in your report, state how much variance is explained by the
# first principal component and how much is explained by the second.

# %%
file_path = 'breast+cancer+wisconsin+diagnostic/wdbc.data'  
data = pd.read_csv(file_path, header=None, index_col=0)

y = data[1]  # Labels (M or B)
X = data.loc[:, 2:]  # Features

pca = PCA(n_components=2)
X_2d = pca.fit_transform(X)


plt.figure(figsize=(10, 6))

for l in np.unique(y):
    
    label_par = 'Bening' 
    c_par = 'b'
    if l == 'M':
        label_par = 'Maligant' 
        c_par = 'r'
        
    plt.scatter(X_2d[y == l, 0], X_2d[y == l, 1], label=label_par, c=c_par, alpha=0.5) 

plt.title("PCA for Breast Cancer Dataset reduced to 2 dimensions")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend()
plt.savefig("plots/clustering1.png")
plt.show()


variance = pca.explained_variance_ratio_
print("Ratio of variance explained by the first principal component:", variance[0])
print("Ratio of variance explained by the second principal component:", variance[1])
# Out:
# Ratio of variance explained by the first principal component: 0.9820446715106612
# Ratio of variance explained by the second principal component: 0.016176489863511015

# %% [markdown]
# #### Task 5
#
# Fit a Gaussian mixture model with 2 components using the 2-dimensional
# data and display the (soft) clusters using a scatter plot. The colour of
# each point in the scatter plot should represent the responsibilities associated with that point—so there will be more than 2 colours in your
# scatter plot. (The rightmost plot on slide 6 of the lecture on k-means
# and mixtures of Gaussians is an example of this sort of plot.)

# %%
gmm = GaussianMixture(n_components=2)
gmm.fit(X_2d)
responsibilities = gmm.predict_proba(X_2d)

plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_2d[:, 0], X_2d[:, 1], c=responsibilities[:, 0], cmap='RdYlBu', alpha=0.5)

plt.title("Gaussian Mixture Model for predictiong")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.colorbar(scatter, label='Responsibility of a datapoint for cluster 1')
plt.savefig("plots/clustering2.png")
plt.show()
# Out:
# [[1160.1425737  -293.91754364]
#  [1269.12244319   15.63018184]
#  [ 995.79388896   39.15674324]
#  ...
#  [ 314.50175618   47.55352518]
#  [1124.85811531   34.12922497]
#  [-771.52762188  -88.64310636]]

# %% [markdown]
# #### Task 6
#
# You now have 2 different sorts of (coloured) scatter plot. Identify
# the main differences between them and explain these differences.

# %% [markdown]
# #### Task 7
#
# Use an SVM approach to learn a classifier from the first 450 datapoints of the Breast Cancer Wisconsin (Diagnostic) dataset and report
# its accuracy on the the last 119 datapoints (i.e. use these 119 datapoints as a test set). Attempt to maximise the test set accuracy by
# choosing an appropriate kernel and appropriate degree of regularisation. Feel free to score candidate SVM predictors on the test set to see
# what works best (so the test set is really acting as a validation set, not
# a test set in the strict sense)

# %%
X_train, X_test = X.iloc[:450], X.iloc[450:]
y_train, y_test = y.iloc[:450], y.iloc[450:]

# Scaling the features for better performance
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

kernels = ['linear', 'poly', 'rbf', 'sigmoid']
C_values = [0.1, 1, 10, 100]
best_accuracy = 0
best_kernel = ''
best_C = 0

for kernel in kernels:
    for C in C_values:
        svm_model = SVC(kernel=kernel, C=C)
        svm_model.fit(X_train, y_train)
        y_pred = svm_model.predict(X_test)
        
        score = svm_model.score(X_train, y_train)       
        print("The training score accuracy is: ", score)
        accuracy_score = svm_model.score(X_test, y_test)         
        print("Accuracy on test data is: ", accuracy_score)
        
        print("Kernel:", kernel)
        print("C Value:", C)
        print()
        
        if accuracy_score > best_accuracy:
            best_accuracy = accuracy_score
            best_kernel = kernel
            best_C = C
        
        
print("Best Accuracy:", best_accuracy)
print("Best Kernel:", best_kernel)
print("Best C Value:", best_C)
# Out:
# The training score accuracy is:  0.9844444444444445
# Accuracy on test data is:  0.9747899159663865
# Kernel: linear
# C Value: 0.1
#
# The training score accuracy is:  0.9866666666666667
# Accuracy on test data is:  0.9663865546218487
# Kernel: linear
# C Value: 1
#
# The training score accuracy is:  0.9844444444444445
# Accuracy on test data is:  0.9747899159663865
# Kernel: linear
# C Value: 10
#
# The training score accuracy is:  0.9911111111111112
# Accuracy on test data is:  0.9915966386554622
# Kernel: linear
# C Value: 100
#
# The training score accuracy is:  0.8311111111111111
# Accuracy on test data is:  0.9327731092436975
# Kernel: poly
# C Value: 0.1
#
# The training score accuracy is:  0.92
# Accuracy on test data is:  0.9747899159663865
# Kernel: poly
# C Value: 1
#
# The training score accuracy is:  0.9777777777777777
# Accuracy on test data is:  0.9831932773109243
# Kernel: poly
# C Value: 10
#
# The training score accuracy is:  0.9977777777777778
# Accuracy on test data is:  0.9495798319327731
# Kernel: poly
# C Value: 100
#
# The training score accuracy is:  0.9666666666666667
# Accuracy on test data is:  0.9663865546218487
# Kernel: rbf
# C Value: 0.1
#
# The training score accuracy is:  0.9844444444444445
# Accuracy on test data is:  0.9747899159663865
# Kernel: rbf
# C Value: 1
#
# The training score accuracy is:  0.9888888888888889
# Accuracy on test data is:  0.9831932773109243
# Kernel: rbf
# C Value: 10
#
# The training score accuracy is:  1.0
# Accuracy on test data is:  0.9243697478991597
# Kernel: rbf
# C Value: 100
#
# The training score accuracy is:  0.9666666666666667
# Accuracy on test data is:  0.9831932773109243
# Kernel: sigmoid
# C Value: 0.1
#
# The training score accuracy is:  0.9511111111111111
# Accuracy on test data is:  0.9327731092436975
# Kernel: sigmoid
# C Value: 1
#
# The training score accuracy is:  0.9244444444444444
# Accuracy on test data is:  0.8991596638655462
# Kernel: sigmoid
# C Value: 10
#
# The training score accuracy is:  0.9244444444444444
# Accuracy on test data is:  0.8823529411764706
# Kernel: sigmoid
# C Value: 100
#
# Best Accuracy: 0.9915966386554622
# Best Kernel: linear
# Best C Value: 100

# %% [markdown]
# #### Task 8
#
# Repeat the previous task but now use the 2-dimensional dataset
# (plus class labels) produced earlier via PCA.

# %%
pca = PCA(n_components=2)
X_2d = pca.fit_transform(X)

X_train_2d, X_test_2d = X_2d[:450], X_2d[450:]
y_train_2d, y_test_2d = y.iloc[:450], y.iloc[450:]

kernels = ['linear', 'poly', 'rbf', 'sigmoid']
C_values = [0.1, 1, 10, 100]
best_accuracy_2d = 0
best_kernel_2d = ''
best_C_2d = 0

for kernel in kernels:
    for C in C_values:
        svm_model_2d = SVC(kernel=kernel, C=C)
        svm_model_2d.fit(X_train_2d, y_train_2d)
        y_pred_2d = svm_model_2d.predict(X_test_2d)
       
        score = svm_model_2d.score(X_train_2d, y_train_2d)       
        print("The training score is: ", score)
        accuracy_score = svm_model_2d.score(X_test_2d, y_test_2d)        
        print("Accuracy on test data is: ", accuracy_score)
        
        print("Kernel:", kernel)
        print("C Value:", C)
        print()
        if accuracy_score > best_accuracy_2d:
            best_accuracy_2d = accuracy_score
            best_kernel_2d = kernel
            best_C_2d = C

        
print("Best Accuracy:", best_accuracy_2d)
print("Best Kernel:", best_kernel_2d)
print("Best C Value:", best_C_2d)
# Out:
# The training score is:  0.9288888888888889
# Accuracy on test data is:  0.9327731092436975
# Kernel: linear
# C Value: 0.1
#
# The training score is:  0.9288888888888889
# Accuracy on test data is:  0.9327731092436975
# Kernel: linear
# C Value: 1
#
# The training score is:  0.9311111111111111
# Accuracy on test data is:  0.9243697478991597
# Kernel: linear
# C Value: 10
#
# The training score is:  0.9288888888888889
# Accuracy on test data is:  0.907563025210084
# Kernel: linear
# C Value: 100
#
# The training score is:  0.7977777777777778
# Accuracy on test data is:  0.9243697478991597
# Kernel: poly
# C Value: 0.1
#
# The training score is:  0.8422222222222222
# Accuracy on test data is:  0.9159663865546218
# Kernel: poly
# C Value: 1
#
# The training score is:  0.86
# Accuracy on test data is:  0.9327731092436975
# Kernel: poly
# C Value: 10
#
# The training score is:  0.9133333333333333
# Accuracy on test data is:  0.907563025210084
# Kernel: poly
# C Value: 100
#
# The training score is:  0.9066666666666666
# Accuracy on test data is:  0.9495798319327731
# Kernel: rbf
# C Value: 0.1
#
# The training score is:  0.9133333333333333
# Accuracy on test data is:  0.9495798319327731
# Kernel: rbf
# C Value: 1
#
# The training score is:  0.9311111111111111
# Accuracy on test data is:  0.9327731092436975
# Kernel: rbf
# C Value: 10
#
# The training score is:  0.9333333333333333
# Accuracy on test data is:  0.9243697478991597
# Kernel: rbf
# C Value: 100
#
# The training score is:  0.8977777777777778
# Accuracy on test data is:  0.9411764705882353
# Kernel: sigmoid
# C Value: 0.1
#
# The training score is:  0.8911111111111111
# Accuracy on test data is:  0.8739495798319328
# Kernel: sigmoid
# C Value: 1
#
# The training score is:  0.8733333333333333
# Accuracy on test data is:  0.8319327731092437
# Kernel: sigmoid
# C Value: 10
#
# The training score is:  0.8733333333333333
# Accuracy on test data is:  0.8319327731092437
# Kernel: sigmoid
# C Value: 100
#
# Best Accuracy: 0.9495798319327731
# Best Kernel: rbf
# Best C Value: 0.1
